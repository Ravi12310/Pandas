# %% [markdown]
# ### Pandas

# %% [markdown]
# ### File read and write operations

# %%
import pandas as pd

# %%
draft1 = pd.read_csv("C:/Users/PC/Downloads/pandas demo.csv")    ## path name

# %%
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
type(draft1)
# Out:
# pandas.core.frame.DataFrame

# %%
draft1.head()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft1.tail()
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft2 = pd.read_table("pandas demo2.csv")

# %%
draft2
# Out:
#      test  test.1  test.2  test.3  test.4
# 0   ravi1   ravi2   ravi3   ravi4   ravi5
# 1  kumar1  kumar2  kumar3  kumar4  kumar5
# 2  royal1  royal2  royal3  royal4  royal5

# %%
draft2.head()
# Out:
#      test  test.1  test.2  test.3  test.4
# 0   ravi1   ravi2   ravi3   ravi4   ravi5
# 1  kumar1  kumar2  kumar3  kumar4  kumar5
# 2  royal1  royal2  royal3  royal4  royal5

# %%
draft2.head(1)   ## it will give the specified rows in a upward
# Out:
#     test test.1 test.2 test.3 test.4
# 0  ravi1  ravi2  ravi3  ravi4  ravi5

# %%
draft2.tail(1)    ## it will give the specified rows in a downward
# Out:
#      test  test.1  test.2  test.3  test.4
# 2  royal1  royal2  royal3  royal4  royal5

# %%
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft2 = pd.read_csv("pandas demo2.csv")

# %%
draft2
# Out:
#              test\ttest\ttest\ttest\ttest
# 0       ravi1\travi2\travi3\travi4\travi5
# 1  kumar1\tkumar2\tkumar3\tkumar4\tkumar5
# 2  royal1\troyal2\troyal3\troyal4\troyal5

# %%
draft2 = pd.read_csv("pandas demo2.csv",sep='\t')

# %%
draft2
# Out:
#      test  test.1  test.2  test.3  test.4
# 0   ravi1   ravi2   ravi3   ravi4   ravi5
# 1  kumar1  kumar2  kumar3  kumar4  kumar5
# 2  royal1  royal2  royal3  royal4  royal5

# %%
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft1 = pd.read_table("pandas demo.csv",sep=',')

# %%
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft1
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
draft1 = pd.read_csv("pandas demo.csv",header = None)

# %%
draft1
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df = pd.read_csv("pandas demo.csv",names = ['asdjd','sjdsjd','djddj','sdusgu',"ravi",'kumar','ravi1'])  ## it will change the names as headings

# %%
df
# Out:
#   asdjd sjdsjd djddj sdusgu     ravi  kumar  ravi1
# 0     a      b     c      d  message    NaN    NaN
# 1     1      2     3      4    hello    NaN    NaN
# 2     5      6     7      8    world    NaN    NaN
# 3     9     10    11     12      foo    NaN    NaN

# %%
parsed = pd.read_csv("keys.csv")
parsed
# Out:
#   key1 key2  value1  value2
# 0  one    a       1       2
# 1  one    b       1      11
# 2  one    c       2      12
# 3  one    d       1      13
# 4  one    e       3      14
# 5  two    f       5      15
# 6  two    a       1      16
# 7  two    b       2      17
# 8  two    c       6      20

# %%
parsed = pd.read_csv("keys.csv",index_col=['key1',"key2"])  ## index_col means it highlighted the partcular given index 
parsed
# Out:
#            value1  value2
# key1 key2
# one  a          1       2
#      b          1      11
#      c          2      12
#      d          1      13
#      e          3      14
# two  f          5      15
#      a          1      16
#      b          2      17
#      c          6      20

# %%
df = pd.read_csv("example.csv")
df
# Out:
#                                                                       # hey!
# a                                                  b        c   d    message
# # just wanted to make thinhs more difficult for... NaN      NaN NaN      NaN
# # who reads CSV files with computers                anyway? NaN NaN      NaN
# 1                                                  2        3   4      hello
# 5                                                  6        7   8      world
# 9                                                  10       11  12       foo

# %%
df = pd.read_csv("example.csv",skiprows=[0,2,3])  ## skiprows means it skips the rows whatever we want
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
result = pd.read_csv("ex1.csv")
result
# Out:
#   something  a   b   c     d message
# 0       one  1   2   3   4.0     NaN
# 1       two  5   6   8   NaN   world
# 2     three  9  10  11  12.0     foo

# %%
result = pd.read_csv("ex1.csv")
result
pd.isnull(result)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False  False   True    False
# 2      False  False  False  False  False    False

# %%
## In the dataset if we have NaN values then it will give True otherwise False

# %%
result = pd.read_csv("ex1.csv",na_values=['NULL'])
result
# Out:
#   something  a   b   c     d message
# 0       one  1   2   3   4.0     NaN
# 1       two  5   6   8   NaN   world
# 2     three  9  10  11  12.0     foo

# %%
draft3 = pd.read_excel("test1.xlsx")
draft3
# Out:
#   djodjo djeodj  ravi kumar
# 0    NaN    NaN   NaN   NaN
# 1    NaN    NaN   NaN   NaN
# 2    NaN     de  mkfk   NaN
# 3    NaN    NaN   NaN   NaN
# 4    e22    NaN   NaN   ffe
# 5    NaN    NaN   NaN   NaN
# 6    NaN    444   NaN   NaN
# 7    7gg    NaN    55    66
# 8    NaN    NaN   NaN   NaN
# 9    NaN    NaN  rhrh   NaN

# %%
draft3 = pd.read_excel("test1.xlsx",sheet_name='Sheet2')
draft3
# Out:
#     sd  frr    dfr Unnamed: 3
# 0  NaN  NaN    NaN        NaN
# 1  NaN   rr     fr        NaN
# 2  NaN  NaN    NaN        NaN
# 3  NaN  NaN    NaN        NaN
# 4  NaN  333  fggbb        NaN
# 5  NaN  NaN    NaN        NaN
# 6  fgf  NaN    NaN        rfr

# %%
url = "https://www.basketball-reference.com/leagues/NBA_2015_totals.html"

b_data = pd.read_html(url)  ## To read the data from specified url
b_data
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
type(b_data)  ## by taking url data it always gives in a list form
# Out:
# list

# %%
b_data[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
b_data[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-75-21741bfa2caf> in <module>
# ----> 1 b_data[1]
#
# IndexError: list index out of range

# %%
df = b_data[0]
df
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
df.head()
# Out:
#   Rk         Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  DRB  \
# 0  1     Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79  222
# 1  2   Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9   19
# 2  3   Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199  324
# 3  4    Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23   54
# 4  5  Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27  220
#
#    TRB  AST STL BLK  TOV   PF   PTS
# 0  301   68  27  22   60  147   398
# 1   28   16  16   7   14   24    94
# 2  523   66  38  86   99  222   537
# 3   77   15   4   9    9   30    60
# 4  247  129  41   7  116  167  1035
#
# [5 rows x 30 columns]

# %%
df.head(10)
# Out:
#   Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1  2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2  3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3  4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4  5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# 5  5   Arron Afflalo  SG  29  DEN  53  53  1750  281  657  ...  .841   21
# 6  5   Arron Afflalo  SG  29  POR  25  19   752   94  227  ...  .851    6
# 7  6   Alexis Ajinça   C  26  NOP  68   8   957  181  329  ...  .818  104
# 8  7  Furkan Aldemir  PF  23  PHI  41   9   540   40   78  ...  .481   78
# 9  8    Cole Aldrich   C  26  NYK  61  16   976  144  301  ...  .781  101
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  222  301   68  27  22   60  147   398
# 1   19   28   16  16   7   14   24    94
# ...

# %%
df.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [5 rows x 30 columns]

# %%
df['MP']  ## it gives the particular column
# Out:
# 0      1287
# 1       248
# 2      1771
# 3       215
# 4      2502
#        ...
# 670    2434
# 671    1605
# 672     829
# 673    1487
# 674    1731
# Name: MP, Length: 675, dtype: object

# %%
df[['MP',"Tm"]]
# Out:
#        MP   Tm
# 0    1287  NYK
# 1     248  MEM
# 2    1771  OKC
# 3     215  MIN
# 4    2502  TOT
# ..    ...  ...
# 670  2434  TOT
# 671  1605  MIN
# 672   829  BRK
# 673  1487  CHO
# 674  1731  BOS
#
# [675 rows x 2 columns]

# %%
type(df["MP"])
# Out:
# pandas.core.series.Series

# %%
type(df[["MP"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
titanic_data = pd.read_csv("titanic.csv")
titanic_data
# Out:
#      passenger_id  pclass                            name     sex   age  \
# 0             295       1     Thayer, Mr. John Borland Jr    male  17.0
# 1            1150       3        Risien, Mr. Samuel Beard    male   NaN
# 2              89       1          Davidson, Mr. Thornton    male  31.0
# 3            1063       3  Nirva, Mr. Iisakki Antino Aijo    male  41.0
# 4            1020       3              Minkoff, Mr. Lazar    male  21.0
# ..            ...     ...                             ...     ...   ...
# 454          1194       3              Sdycoff, Mr. Todor    male   NaN
# 455           403       2    Eitemiller, Mr. George Floyd    male  23.0
# 456           108       1         Fleming, Miss. Margaret  female   NaN
# 457           510       2        Mudd, Mr. Thomas Charles    male  16.0
# 458          1265       3       Van Impe, Miss. Catharina  female  10.0
#
#      sibsp  parch            ticket      fare cabin embarked boat  body  \
# ...

# %%
titanic_data.head()
# Out:
#    passenger_id  pclass                            name   sex   age  sibsp  \
# 0           295       1     Thayer, Mr. John Borland Jr  male  17.0      0
# 1          1150       3        Risien, Mr. Samuel Beard  male   NaN      0
# 2            89       1          Davidson, Mr. Thornton  male  31.0      1
# 3          1063       3  Nirva, Mr. Iisakki Antino Aijo  male  41.0      0
# 4          1020       3              Minkoff, Mr. Lazar  male  21.0      0
#
#    parch            ticket      fare cabin embarked boat  body  \
# 0      2             17421  110.8833   C70        C    B   NaN
# 1      0            364498   14.5000   NaN        S  NaN   NaN
# 2      0        F.C. 12750   52.0000   B71        S  NaN   NaN
# 3      0  SOTON/O2 3101272    7.1250   NaN        S  NaN   NaN
# 4      0            349211    7.8958   NaN        S  NaN   NaN
#
#              home.dest
# 0        Haverford, PA
# 1                  NaN
# 2         Montreal, PQ
# 3  Finland Sudbury, ON
# ...

# %%
titanic_data[['name','fare']]
# Out:
#                                name      fare
# 0       Thayer, Mr. John Borland Jr  110.8833
# 1          Risien, Mr. Samuel Beard   14.5000
# 2            Davidson, Mr. Thornton   52.0000
# 3    Nirva, Mr. Iisakki Antino Aijo    7.1250
# 4                Minkoff, Mr. Lazar    7.8958
# ..                              ...       ...
# 454              Sdycoff, Mr. Todor    7.8958
# 455    Eitemiller, Mr. George Floyd   13.0000
# 456         Fleming, Miss. Margaret  110.8833
# 457        Mudd, Mr. Thomas Charles   10.5000
# 458       Van Impe, Miss. Catharina   24.1500
#
# [459 rows x 2 columns]

# %%
titanic_data.head(2)
# Out:
#    passenger_id  pclass                         name   sex   age  sibsp  \
# 0           295       1  Thayer, Mr. John Borland Jr  male  17.0      0
# 1          1150       3     Risien, Mr. Samuel Beard  male   NaN      0
#
#    parch  ticket      fare cabin embarked boat  body      home.dest
# 0      2   17421  110.8833   C70        C    B   NaN  Haverford, PA
# 1      0  364498   14.5000   NaN        S  NaN   NaN            NaN

# %%
titanic_data.dtypes
# Out:
# passenger_id      int64
# pclass            int64
# name             object
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# ticket           object
# fare            float64
# cabin            object
# embarked         object
# boat             object
# body            float64
# home.dest        object
# dtype: object

# %%
## read the data in dataframe format
## print first five data
## print last two data
## give your own column name
## select on column and print its datatype

# %%
url = pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv",sep=';')

# %%
url
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
url = pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv",sep=';',names=['ravi',"kumar",'sudh'])
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,10,11,12,13,15,16,17,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
url
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
url.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
url.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
url.head(5)
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
url.tail(2)
# Out:
#        age         job  marital            education default housing loan  \
# 41186   44  technician  married  professional.course      no      no   no
# 41187   74     retired  married  professional.course      no     yes   no
#
#         contact month day_of_week  ...  campaign  pdays  previous  \
# 41186  cellular   nov         fri  ...         1    999         0
# 41187  cellular   nov         fri  ...         3    999         1
#
#           poutcome emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  \
# 41186  nonexistent         -1.1          94.767          -50.8      1.028
# 41187      failure         -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [2 rows x 21 columns]

# %%
df = pd.read_csv("https://raw.githubusercontent.com/akhil12028/Bank-Marketing-data-set-analysis/master/bank-additional-full.csv",
                names=["ravi1",'ravi2','hsiuh','shidj','hduidh'])

# %%
df['ravi1'].dtype
# Out:
# dtype('O')

# %%
df
# Out:
#                                                    ravi1  ravi2  hsiuh  shidj  \
# 0      age;"job";"marital";"education";"default";"hou...    NaN    NaN    NaN
# 1      56;"housemaid";"married";"basic.4y";"no";"no";...    NaN    NaN    NaN
# 2      57;"services";"married";"high.school";"unknown...    NaN    NaN    NaN
# 3      37;"services";"married";"high.school";"no";"ye...    NaN    NaN    NaN
# 4      40;"admin.";"married";"basic.6y";"no";"no";"no...    NaN    NaN    NaN
# ...                                                  ...    ...    ...    ...
# 41184  73;"retired";"married";"professional.course";"...    NaN    NaN    NaN
# 41185  46;"blue-collar";"married";"professional.cours...    NaN    NaN    NaN
# 41186  56;"retired";"married";"university.degree";"no...    NaN    NaN    NaN
# 41187  44;"technician";"married";"professional.course...    NaN    NaN    NaN
# 41188  74;"retired";"married";"professional.course";"...    NaN    NaN    NaN
#
#        hduidh
# 0         NaN
# ...

# %%
df.dtypes
# Out:
# ravi1      object
# ravi2     float64
# hsiuh     float64
# shidj     float64
# hduidh    float64
# dtype: object

# %%
df.isnull()
# Out:
#        ravi1  ravi2  hsiuh  shidj  hduidh
# 0      False   True   True   True    True
# 1      False   True   True   True    True
# 2      False   True   True   True    True
# 3      False   True   True   True    True
# 4      False   True   True   True    True
# ...      ...    ...    ...    ...     ...
# 41184  False   True   True   True    True
# 41185  False   True   True   True    True
# 41186  False   True   True   True    True
# 41187  False   True   True   True    True
# 41188  False   True   True   True    True
#
# [41189 rows x 5 columns]

# %%
df['ravi1']
# Out:
# 0        age;"job";"marital";"education";"default";"hou...
# 1        56;"housemaid";"married";"basic.4y";"no";"no";...
# 2        57;"services";"married";"high.school";"unknown...
# 3        37;"services";"married";"high.school";"no";"ye...
# 4        40;"admin.";"married";"basic.6y";"no";"no";"no...
#                                ...
# 41184    73;"retired";"married";"professional.course";"...
# 41185    46;"blue-collar";"married";"professional.cours...
# 41186    56;"retired";"married";"university.degree";"no...
# 41187    44;"technician";"married";"professional.course...
# 41188    74;"retired";"married";"professional.course";"...
# Name: ravi1, Length: 41189, dtype: object

# %%
df.isnull().sum()
# Out:
# ravi1         0
# ravi2     41189
# hsiuh     41189
# shidj     41189
# hduidh    41189
# dtype: int64
